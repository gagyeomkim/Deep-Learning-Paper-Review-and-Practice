# %% [markdown]
# <a href="https://colab.research.google.com/github/gagyeomkim/Deep-Learning-Paper-Review-and-Practice/blob/main/code_practice/BERT/WordPiece.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## BERT의 Subword tokenizer: WordPiece

# %% [markdown]
# - code by https://wikidocs.net/217013

# %%
# !pip install transformers

# %%
import pandas as pd
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")   # Bert-base의 토크나이저
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
result = tokenizer.tokenize('Here is the sentence I want embeddings for.')
print(result)
# Out:
# ['here', 'is', 'the', 'sentence', 'i', 'want', 'em', '##bed', '##ding', '##s', 'for', '.']

# %% [markdown]
# - `.vocab[]`: BERT의 단어집합에 특정 단어가 있는지 조회

# %%
print(tokenizer.vocab['here'])
# Out:
# 2182

# %%
print(tokenizer.vocab['embeddings'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3459640444.py in <cell line: 0>()
# ----> 1 print(tokenizer.vocab['embeddings'])
#
# KeyError: 'embeddings'

# %%
print(tokenizer.vocab['em'])
print(tokenizer.vocab['##bed'])
print(tokenizer.vocab['##ding'])
print(tokenizer.vocab['##s'])
# Out:
# 7861
# 8270
# 4667
# 2015

# %%
# BERT의 단어집합을 vocabulary.txt에 저장
with open('vocabulary.txt','w') as f:
    for token in tokenizer.vocab.keys():
        f.write(token + '\n')

# %%
df = pd.read_fwf('vocabulary.txt', header=None)
df
# Out:
#                0
# 0          [PAD]
# 1      [unused0]
# 2      [unused1]
# 3      [unused2]
# 4      [unused3]
# ...          ...
# 30517        ##．
# 30518        ##／
# 30519        ##：
# 30520        ##？
# 30521        ##～
#
# [30522 rows x 1 columns]

# %%
print('단어집합의 크기 :',len(df))
# Out:
# 단어집합의 크기 : 30522

# %%
df.loc[4667].values[0]
# Out:
# '##ding'

# %%
df.loc[102].values[0]
# Out:
# '[SEP]'
